# %% [markdown]
# <a href="https://colab.research.google.com/github/vanlee913/bigdata/blob/main/0420%E6%9C%9F%E4%B8%AD%E8%80%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)
library(SportsAnalytics)

# %%
NBA1819<-fetch_NBAPlayerStatistics("18-19")

# %%
NBA1819
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Alex Abrines     OKL  SG       31           588
# 2   NBA    Quincy Acy       PHO  SF       10           121
# 3   NBA    Jaylen Adams     ATL  PG       34           425
# 4   NBA    Steven Adams     OKL  C        80          2667
# 5   NBA    Bam Adebayo      MIA  C        82          1908
# 6   NBA    Deng Adel        CLE  SF       18           196
# 7   NBA    De Akoon-purcell DEN  SG        7            23
# 8   NBA    Lamarcu Aldridge SAN  PF       81          2689
# 9   NBA    Rawle Alkins     CHI  SG       10           120
# 10  NBA    Grayson Allen    UTA  SG       37           414
# 11  NBA    Jarrett Allen    BRO  C        80          2095
# 12  NBA    Kadeem Allen     NYK  SG       19           414
# 13  NBA    Al-farouq Aminu  POR  PF       81          2289
# 14  NBA    Justin Anderson  ATL  SG       46           460
# 15  NBA    Kyle Anderson    MEM  SF       43          1281
# ...

# %%
x <- NBA1819$GamesPlayed

# %%
order(
  x,
  decreasing = T,
  method = "auto")
# Out:
#   [1]   5  40  45  66  87 169 186 208 212 224 231 246 257 277 350 364 383 404
#  [19] 444 484 497   8  13  22  24  41  57  97 107 128 168 170 171 187 256 310
#  [37] 431 434 438 525 526   4  11  67 121 178 194 197 269 305 309 439 447 453
#  [55] 493  43 147 180 255 293 390 432 440 441 445 449 467  49  54 150 189 206
#  [73] 477  33  52 109 135 183 201 300 336 346 354 377 406 410 481  48  92 110
#  [91] 139 163 211 335 391 418 423  36 202 239 250 285 337 362 367 443 469 515
# [109] 516 522  73  74 118 123 166 243 306 311 388 435 459 486  78 144 199 214
# [127] 261 356 417 421 485 506 510  18  79 114 142 218 235 339 381 494 509  25
# [145] 167 283 295  56 112 184 220 234 288 291 334 351  23 124 160 182 276 330
# [163] 348 392 140 177 190 209 236 244 251 275 393 433 462 492  21  39  44  89
# [181]  90 215 230 245 249 279 372 464 507 198 266 428 473 520  84 200 205 313
# [199] 338  61  70  82 119 130 137 155 281 307 324 369 394 483 491  63  80 122
# ...

# %%
subset(NBA1819,Team=="OKL")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Alex Abrines     OKL  SG       31           588
# 4   NBA    Steven Adams     OKL  C        80          2667
# 83  NBA    Deonte Burton    OKL  SG       31           239
# 129 NBA    Tyler Davis      OKL  C         1             1
# 138 NBA    Hamidou Diallo   OKL  SG       50           526
# 165 NBA    Raymond Felton   OKL  PG       32           378
# 166 NBA    Terranc Ferguson OKL  SG       74          1934
# 183 NBA    Paul George      OKL  SF       77          2844
# 194 NBA    Jerami Grant     OKL  SF       80          2611
# 196 NBA    Donte Grantham   OKL  SF        2             3
# 371 NBA    Abdel Nader      OKL  SF       61           693
# 377 NBA    Nerlens Noel     OKL  C        77          1057
# 397 NBA    Patric Patterson OKL  PF       63           860
# 440 NBA    Dennis Schroder  OKL  PG       79          2307
# 506 NBA    Russel Westbrook OKL  PG       73          2632
# ...

# %%
NBA1819[grepl("Paul George",NBA1819$Name),]
# Out:
#     League Name        Team Position GamesPlayed TotalMinutesPlayed
# 183 NBA    Paul George OKL  SF       77          2844
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 183 707            1614                292        757             ⋯ 172
#     Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 183 205       34     214           3                 2159        9
#     Ejections FlagrantFouls GamesStarted
# 183 0         0             77

# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("showtext")
library(showtext)
showtext.auto()
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’
#
#
# Loading required package: sysfonts
#
# Loading required package: showtextdb
#
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code

# %%
qplot(
  ThreesMade,
  TotalPoints,
  data=NBA1819
  )
# Out:
# plot without title

# %%
qplot(
  ThreesMade,
  TotalPoints,
  data = NBA1819,
  color=Position
  )
# Out:
# plot without title

# %%
qplot(
  TotalPoints,
  data=NBA1819,
  fill=Position
  )
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
k <- subset(NBA1819,Team=="OKL")

qplot(
  ThreesMade,
  TotalPoints,
  data = k,
  color = ThreesMade,
  geom=c("point","smooth")
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(
  ThreesMade,
  TotalPoints,
  data=NBA1819,
  facets=Position~.
  )
# Out:
# plot without title
