# %% [markdown]
# <a href="https://colab.research.google.com/github/vanlee913/bigdata/blob/main/0323_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)

# %%
library(ggplot2)

# %%
NBA1516<-fetch_NBAPlayerStatistics("15-16")

# %%
NBA1516
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 1   NBA    Quincy Acy       SAC  SF       59           877
# 2   NBA    Jordan Adams     MEM  SG        2            15
# 3   NBA    Steven Adams     OKL  C        80          2019
# 4   NBA    Arron Afflalo    NYK  SG       71          2359
# 5   NBA    Alexis Ajinca    NOR  C        59           863
# 6   NBA    Cole Aldrich     LAC  C        60           802
# 7   NBA    Lamarcu Aldridge SAN  PF       74          2260
# 8   NBA    Cliff Alexander  POR  PF        9            37
# 9   NBA    Lavoy Allen      IND  PF       79          1601
# 10  NBA    Tony Allen       MEM  SG       64          1622
# 11  NBA    Al-farouq Aminu  POR  SF       82          2342
# 12  NBA    Lou Amundson     NYK  PF       29           199
# 13  NBA    Chris Andersen   MEM  PF       27           404
# 14  NBA    Alan Anderson    WAS  SG       13           193
# 15  NBA    James Anderson   SAC  SG       51           721
# ...

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1516)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1516,color=Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1516,color=Team,
geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1516,color=Position,
geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(TotalPoints,data=NBA1516,fill=Position)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(
  FieldGoalsAttempted,
  TotalPoints,
  data=NBA1516,
  facets=Position~.
  )
# Out:
# plot without title

# %%
qplot(
  FieldGoalsAttempted,
  TotalPoints,
  data=NBA1516,
  facets=.~Position
  )
# Out:
# plot without title

# %%
qplot(
  TotalPoints,
  data=NBA1516,
  facets=Position~.,
  binwidth=10
  )
# Out:
# plot without title

# %%
qplot(
  TotalPoints,
  data=NBA1516,
  facets=Position~.,
  binwidth=100
  )
# Out:
# plot without title

# %%
qplot(
  TotalPoints,
  data=NBA1516,
  facets=.~Position,
  binwidth=10
  )
# Out:
# plot without title

# %%
qplot(
  TotalPoints,
  data=NBA1516,
  facets=Team~.,
  binwidth=10
  )
# Out:
# plot without title
